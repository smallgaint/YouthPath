# %% [markdown]
# # 01 온통청년 API 구조 확인
#
# 정책 1~5개만 호출해서 응답 필드와 샘플을 확인한다.

# %%
from clients.ontong_api import fetch_policies, normalize_policy

response = fetch_policies(query='청년 주거', page=1, display=2)
len(response['items']), response['items'][:1]

# %%
samples = [normalize_policy(item) for item in response['items'][:5]]
samples
